# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\users\suraj\anaconda3\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in c:\users\suraj\anaconda3\lib\site-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\suraj\anaconda3\lib\site-packages (from pytesseract) (10.4.0)

# %%
import cv2
import pytesseract

# Set the path to Tesseract OCR executable
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

def extract_license_plate_from_image(image):
    try:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        blurred = cv2.GaussianBlur(gray, (5, 5), 0)
        edged = cv2.Canny(blurred, 100, 200)

        contours, _ = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

        for contour in contours:
            epsilon = 0.02 * cv2.arcLength(contour, True)
            approx = cv2.approxPolyDP(contour, epsilon, True)
            if len(approx) == 4:
                x, y, w, h = cv2.boundingRect(contour)
                cropped = image[y:y+h, x:x+w]
                text = pytesseract.image_to_string(cropped, config='--psm 8').strip()

                if len(text) >= 5:  # crude filter for plate text
                    print(f"Detected License Plate: {text}")
                    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
                    cv2.putText(image, text, (x, y - 10),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
                    break
    except Exception as e:
        print(f"Error in processing image: {e}")
    return image

# Initialize webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
else:
    print("Starting license plate recognition. Press 'q' to quit.")

    while True:
        ret, frame = cap.read()
        if not ret:
            print("Failed to grab frame.")
            break

        frame = cv2.resize(frame, (800, 600))
        processed_frame = extract_license_plate_from_image(frame)
        cv2.imshow("License Plate Detection", processed_frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# Starting license plate recognition. Press 'q' to quit.
# Detected License Plate: enmmerecs
# Detected License Plate: ee ne
# Detected License Plate: —— ee
# Detected License Plate: ——— ee“
# Detected License Plate: ee eee
# Detected License Plate: a" |)
# Detected License Plate: I —O—E—————————— tC
# Detected License Plate: ee ee
# Detected License Plate: ——— i
# Detected License Plate: ee ee
# Detected License Plate: RJ14CV0002
# Detected License Plate: -RJ1ZCV0002
# Detected License Plate: -RJ1ZCV¥0002
# Detected License Plate: F-RJ1ZC¥0002
# Detected License Plate: -RJ1ZCV¥0002
# Detected License Plate: -RJ1ZCV0002
# Detected License Plate: -RJ14CV0002
# Detected License Plate: -RJ14CV0002
# Detected License Plate: -RJ1ZCV0002
# Detected License Plate: -RJ14CV0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: -RJ1ZCV0002
# Detected License Plate: -RJ1ZCV¥0002
# Detected License Plate: -RJ1ZCV¥0002
# Detected License Plate: -RJ1ZCV¥0002
# Detected License Plate: RJ1ZCV¥0002
# Detected License Plate: RJ1ZC¥0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: -RJ1ZCV0002
# Detected License Plate: -RJ1ZCV0002
# Detected License Plate: RJ1ZC¥0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: -RJ14C¥0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: -RJ1ZCV¥0002
# Detected License Plate: -RJ1ZCV0002
# Detected License Plate: -RJ14C¥0002
# Detected License Plate: -RJ1ZCV¥0002
# Detected License Plate: -RJ14C¥0002
# Detected License Plate: -RJ14C¥0002
# Detected License Plate: ~RJ14C¥0002
# Detected License Plate: -RJ1ZCV0002
# Detected License Plate: -RJ1ZCV0002
# Detected License Plate: -RJ1ZCV0002
# Detected License Plate: -RJ1ZCV¥0002
# Detected License Plate: -RJ1ZC 0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: -RJ14CV0002
# Detected License Plate: RJ1ZCV0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: RJ1ZC¥0002
# Detected License Plate: RI1ZC¥0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: ERJIZC¥0002
# Detected License Plate: ERJ1<C¥0002
# Detected License Plate: ERJ14c¥0002
# Detected License Plate: RJ1ZC¥0002
# Detected License Plate: RJ1ZC¥0002
# Detected License Plate: RJ1ZC¥0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: -RJ1ZCV0002
# Detected License Plate: -RJ14C¥0002
# Detected License Plate: -RJ14C¥0002
# Detected License Plate: -RJ14C¥0002
# Detected License Plate: —" oe
# Detected License Plate: —— ae
# Detected License Plate: PRI 1LC¥ 0002
# Detected License Plate: mR J14cV 0002
# Detected License Plate: mR JI ACV 0002
# Detected License Plate: mRJ1Zc¥0002
# Detected License Plate: RJ 14cV0002
# Detected License Plate: ~RI14CV0002
# Detected License Plate: “RJ LCV 0002
# Detected License Plate: “RJ 14cV0002
# Detected License Plate: ~RJ14CVO0002
# Detected License Plate: “RII ZCV0002
# Detected License Plate: ~RJ1LCVO002
# Detected License Plate: ~RJ14C¥0002
# Detected License Plate: ~RJ14CV0002
# Detected License Plate: “RJ EC¥0002
# Detected License Plate: “RJ LCVO002
# Detected License Plate: ~RJ1LCV0002
# Detected License Plate: “RJ 14cv0002
# Detected License Plate: “RJ 14cV 0002
# Detected License Plate: ~RJ14cV0002
# Detected License Plate: ~RJ14CV0002
# Detected License Plate: mRJ14c¥0002
# Detected License Plate: RII ACV 0002
# Detected License Plate: RII ACV 0002
# Detected License Plate: RII 4C¥ 0002
# Detected License Plate: mR I1 ACV 0002
# Detected License Plate: RII 4CV 0002
# Detected License Plate: mR 1 4c¥0002
# Detected License Plate: RII 4CV 0002
# Detected License Plate: RJ 14C¥ 0002
# Detected License Plate: RII 4C¥ 0002
# Detected License Plate: mRJ14c¥ 0002
# Detected License Plate: rRJ ILC VO002
# Detected License Plate: ~RJ1ACV0002
# Detected License Plate: ~RJ14cV 0002
# Detected License Plate: mJ 1 ACV 0002
# Detected License Plate: PRS 1ACV0002
# Detected License Plate: RJ1ZCV0002
# Detected License Plate: PRS {ACV 0002
# Detected License Plate: rR J 1A V 0002
# Detected License Plate: RJ 14cV 0002
# Detected License Plate: RJ 1ACV0002
# Detected License Plate: mRJ1LcV0002
# Detected License Plate: PRI 1ACV0002
# Detected License Plate: ~RI1LCV0002
# Detected License Plate: PRIVLCVO002
# Detected License Plate: PRI IACV0002
# Detected License Plate: -RJ{ZCV0002
# Detected License Plate: “RJ14CV0002
# Detected License Plate: RJ1ZCV0002
# Detected License Plate: -RJ14C¥0002
# Detected License Plate: -RJ1Zcvo002
# Detected License Plate: LRJ1<CV0002
# Detected License Plate: PI 4<c¥0002,
# Detected License Plate: PII<CV0009
# Detected License Plate: ~d1-c¥0003
# Detected License Plate: ————s
# Detected License Plate: icc ¥0008
# Detected License Plate: RJtdcvo002
# Detected License Plate: FRJ1ZC¥0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: -RJ1ZC¥0002
# Detected License Plate: -RJ14C¥0002
# Detected License Plate: RJ1ZCV0002
# Detected License Plate: -RJ14C¥0002
# Detected License Plate: RJ14C¥0002
# Detected License Plate: RJ14CV0002
# Detected License Plate: FRJ1ZCV0002
# Detected License Plate: RJ14CV0002
# Detected License Plate: ERJ1ZCV0002
# Detected License Plate: RJ14C¥0002
# Detected License Plate: ERJ1ZCV0002
# Detected License Plate: RJ1Zcv0002
# Detected License Plate: -RJ14cvo002
# Detected License Plate: -RJ14cvo002
# Detected License Plate: -RJ1Zcvo002
# Detected License Plate: ERJ1ZcV0002
# Detected License Plate: -RJ14c¥0002
# Detected License Plate: -RJ14cvo002
# Detected License Plate: -RJ1<c¥0002
# Detected License Plate: -RJ1Zc¥0002
# Detected License Plate: ERJ1Zcv0002
# Detected License Plate: RJi<cvo002
# Detected License Plate: RJ 14cV0002
# Detected License Plate: RJ1<cv0002
# Detected License Plate: RJi<cvo002
# Detected License Plate: RJi<cvo002
# Detected License Plate: RJi<cvo002
# Detected License Plate: RJ1<cV0002
# Detected License Plate: RI1c¥0002
# Detected License Plate: RI1<cv0002
# Detected License Plate: RJ1<c¥0002
# Detected License Plate: RIC VO002
# Detected License Plate: RJ14cvo002
# Detected License Plate: RJ1<cvo002
# Detected License Plate: RIC VO002
# Detected License Plate: RJ1<cvo002
# Detected License Plate: RJ14cv0002
# Detected License Plate: RI1<cvo002
# Detected License Plate: RI14cvo002
# Detected License Plate: RII<CV0002
# Detected License Plate: RJ14CV0002
# Detected License Plate: RI14cv0002
# Detected License Plate: RI1<cv0002
# Detected License Plate: RI1<cv0002
# Detected License Plate: RI14cvo002
# Detected License Plate: RI1Cv0002
# Detected License Plate: RIC V0002
# Detected License Plate: RIC V0002
# Detected License Plate: RIC V0002
# Detected License Plate: RJi<cv0002
# Detected License Plate: RJ14CV0002
# Detected License Plate: RJ14CV0002
# Detected License Plate: RJ1<cV0002
# Detected License Plate: RJ14C¥0002
# Detected License Plate: RJt<cv0002
# Detected License Plate: RIT4Cv0002
# Detected License Plate: RJt4cv0002
# Detected License Plate: RS14CV0002
# Detected License Plate: RI14C¥0002
# Detected License Plate: RITCv0002
# Detected License Plate: RJi<cv0002
# Detected License Plate: RI1ZCV0002
# Detected License Plate: RIC V0002
# Detected License Plate: RIC ¥0002
# Detected License Plate: RIC VO002
# Detected License Plate: RIC V0002
# Detected License Plate: RI1<CV0002
# Detected License Plate: RI1ZCVO002
# Detected License Plate: RITCv0002
# Detected License Plate: RIC VO002
# Detected License Plate: RI1<cv0002
# Detected License Plate: LRJ1<cvo002
# Detected License Plate: en ee
# Detected License Plate: sages
# Detected License Plate: nn ee
# Detected License Plate: Bd! Pty
# Detected License Plate: —— oe
# Detected License Plate: —— oe
# Detected License Plate: ee ee
# Detected License Plate: | omg
# Detected License Plate: HROGAY 1229
# Detected License Plate: “HROGAY 1229
# Detected License Plate: “HROGAY 122g
# Detected License Plate: “HROGAY 1229
# Detected License Plate: —— ae
# Detected License Plate: —— ae
